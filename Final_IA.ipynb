# %% [markdown]
# ENCODER

# %%
# !pip install -q langchain-text-splitters
from datasets import load_dataset
from langchain_text_splitters import RecursiveCharacterTextSplitter
import re

# --- 1. CARGA Y REDUCCIÓN DEL DATASET ---
# Cargamos el dataset completo
ds_full = load_dataset("corbt/all-recipes", split="train")

# **Paso de Reducción:** Tomamos solo las primeras 2000 filas para acelerar el proceso.
# Esto reduce drásticamente el número de chunks y el tiempo de vectorización.
ds = ds_full.select(range(2000))

print(f"Dataset reducido a: {len(ds)} documentos.")

def clean_text(s: str) -> str:
    if s is None:
        return ""
    s = str(s)
    s = s.replace("\n", " ")
    s = re.sub(r"\s+", " ", s).strip()
    return s

# Aplicamos limpieza y renombramos la columna
ds = ds.map(lambda row: {
    "text": clean_text(row["input"])
})

print("Texto limpio de la primera receta (ej.):", ds[0]["text"][:300])

# Filtramos filas vacías
ds = ds.filter(lambda row: row["text"] != "")
print(f"Documentos después de filtrar y limpiar: {len(ds)}")


# --- 2. CREACIÓN DE CHUNKS ---

# Aumentamos de 512 a 1500 caracteres.
# Esto asegura que quepan los ingredientes Y las instrucciones completas.
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,     # <--- CAMBIO CRÍTICO
    chunk_overlap=200,   # Un poco de solapamiento para no perder contexto
    separators=["\n\n", "Ingredients:", "Directions:", "\n", " "]
)

docs_texts = []
docs_meta = []

# Iteramos sobre el dataset reducido
for i, row in enumerate(ds):
    chunks = splitter.split_text(row["text"])
    for j, ch in enumerate(chunks):
        docs_texts.append(ch)
        docs_meta.append({
            "doc_id": i,
            "chunk": j
        })

print(f"Total chunks creados (reducido): {len(docs_texts)}")
# Out:
# Dataset reducido a: 2000 documentos.
# Texto limpio de la primera receta (ej.): No-Bake Nut Cookies Ingredients: - 1 c. firmly packed brown sugar - 1/2 c. evaporated milk - 1/2 tsp. vanilla - 1/2 c. broken nuts (pecans) - 2 Tbsp. butter or margarine - 3 1/2 c. bite size shredded rice biscuits Directions: - In a heavy 2-quart saucepan, mix brown sugar, nuts, evaporated milk and
# Documentos después de filtrar y limpiar: 2000
# Total chunks creados (reducido): 2000

# %%
# !pip install -q langchain-community faiss-cpu
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
import torch

# Determinar el dispositivo disponible (GPU si Colab la asignó)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
EMB_MODEL = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"

print(f"\n--- 1. Vectorización Optimizada (Encoder) ---")
print(f"Dispositivo de procesamiento: {DEVICE}")
print(f"Cargando modelo de embedding: {EMB_MODEL}...")

# *** CAMBIO CLAVE: Especificar device y usar batch_size ***
# batch_size=128 permite procesar 128 chunks al mismo tiempo en la GPU, acelerando el proceso
embeddings = HuggingFaceEmbeddings(
    model_name=EMB_MODEL,
    model_kwargs={'device': DEVICE},
    encode_kwargs={'batch_size': 128} # Aumenta la velocidad usando lotes
)

# 2. Creación del Vector Store
print("Creando FAISS vectorstore...")
# Este paso ahora será mucho más rápido
vectorstore = FAISS.from_texts(
    texts=docs_texts,
    embedding=embeddings,
    metadatas=docs_meta
)

print("FAISS vectorstore creada exitosamente.")

# Persistir la base de datos (vital si el proceso falla, para no rehacerlo)
FAISS_PATH = "/content/recetas_faiss_index"
vectorstore.save_local(FAISS_PATH)
print(f"Vectorstore guardada localmente en: {FAISS_PATH}")
# Out:
# --- 1. Vectorización Optimizada (Encoder) ---
# Dispositivo de procesamiento: cuda
# Cargando modelo de embedding: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2...
# Creando FAISS vectorstore...
# FAISS vectorstore creada exitosamente.
# Vectorstore guardada localmente en: /content/recetas_faiss_index

# %%
def retrieve_recipes(query: str, k: int = 4):
    """
    Realiza una consulta a la base de datos vectorial y retorna los k chunks más relevantes.
    """
    print(f"\n--- 2. Consultando el RAG (Retrieval) ---")

    # Usamos similarity_search_with_score para ver tanto el chunk como su relevancia
    relevant_chunks_with_scores = vectorstore.similarity_search_with_score(query, k=k)

    print(f"\nConsulta: '{query}'")
    print(f"Top {k} chunks más relevantes encontrados:")

    results = []
    for i, (chunk_doc, score) in enumerate(relevant_chunks_with_scores):
        print(f"--- Resultado {i+1} (Score: {score:.4f}) ---")
        # El page_content es el chunk de texto real
        print(f"Contenido (inicio): {chunk_doc.page_content[:300]}...")
        print(f"Metadatos: Doc ID={chunk_doc.metadata['doc_id']}, Chunk ID={chunk_doc.metadata['chunk']}")
        results.append(chunk_doc)
    return results

# --- Ejemplos de Consulta ---
# Recuperar 3 chunks sobre recetas de postres
postre_query = "¿Recetas rápidas sin horno con chocolate?"
retrieved_postres = retrieve_recipes(postre_query, k=3)

print("\n--------------------------------------------------")

# Recuperar 5 chunks sobre recetas de pollo
pollo_query = "¿Cómo marinar y asar pollo al horno para que quede jugoso?"
retrieved_pollo = retrieve_recipes(pollo_query, k=5)
# Out:
# --- 2. Consultando el RAG (Retrieval) ---
#
# Consulta: '¿Recetas rápidas sin horno con chocolate?'
# Top 3 chunks más relevantes encontrados:
# --- Resultado 1 (Score: 14.8637) ---
# Contenido (inicio): Chocolate Fudge Ingredients: - 1/2 c. margarine - 1 tall can evaporated milk - 4 c. sugar - 32 marshmallows - 4 sq. baking chocolate - 9 oz. bar milk chocolate - 12 oz. pkg. semi-sweet chocolate - 1 Tbsp. vanilla - 2 c. chopped nuts Directions: - Combine margarine, milk and sugar in Dutch oven. - Pl...
# Metadatos: Doc ID=189, Chunk ID=0
# --- Resultado 2 (Score: 15.2208) ---
# Contenido (inicio): Reeses Cups(Candy) Ingredients: - 1 c. peanut butter - 3/4 c. graham cracker crumbs - 1 c. melted butter - 1 lb. (3 1/2 c.) powdered sugar - 1 large pkg. chocolate chips Directions: - Combine first four ingredients and press in 13 x 9-inch ungreased pan. - Melt chocolate chips and spread over mixtur...
# Metadatos: Doc ID=4, Chunk ID=0
# --- Resultado 3 (Score: 15.4935) ---
# Contenido (inicio): Instant Creamy Hot Chocolate Ingredients: - 1 large jar powdered creamer - 1 (8 qt. size) box nonfat dry milk powder - 1 (2 lb.) box chocolate flavored drink mix - 1 c. powdered sugar Directions: - Mix all ingredients thoroughly and store in an airtight container. - Use 1/3 cup of the mixture in a c...
# Metadatos: Doc ID=1849, Chunk ID=0
#
# --------------------------------------------------
#
# --- 2. Consultando el RAG (Retrieval) ---
#
# Consulta: '¿Cómo marinar y asar pollo al horno para que quede jugoso?'
# Top 5 chunks más relevantes encontrados:
# --- Resultado 1 (Score: 8.5559) ---
# Contenido (inicio): Chicken Casserole Ingredients: - chicken - Stove Top stuffing - cream of chicken soup or cream of mushroom (better with cream of chicken soup) Directions: - Cook chicken and debone. - Cut into small pieces. - Cook Stove Top stuffing as directed. - In greased pan, layer stuffing, chicken and soup. - ...
# Metadatos: Doc ID=1978, Chunk ID=0
# --- Resultado 2 (Score: 8.7107) ---
# Contenido (inicio): Easy Oven-Fried Chicken Ingredients: - 1 c. flour - salt (as desired) - 1/4 tsp. pepper - 2 tsp. paprika - 1/2 c. shortening (half butter) - 1 frying chicken, cut in serving pieces or equivalent pieces of your choice Directions: - Heat oven to 425°. - Melt shortening in 13 x 9 1/2-inch pan. Mix dry ...
# Metadatos: Doc ID=1783, Chunk ID=0
# --- Resultado 3 (Score: 8.9101) ---
# Contenido (inicio): Chicken And Stuffing Bake Ingredients: - 3 c. cut cooked chicken or turkey - 1 medium stalk celery, chopped - 1/2 c. water - 1 c. condensed cream of chicken soup - 3 1/2 c. herb seasoned croutons - 1 medium onion - 1/3 c. margarine or butter - 1 1/2 c. water Directions: - Place chicken in ungreased ...
# Metadatos: Doc ID=882, Chunk ID=0
# --- Resultado 4 (Score: 9.1680) ---
# Contenido (inicio): Chicken And Dressing Casserole Ingredients: - 1 lb. baked shredded chicken breasts - 1 box Stove Top chicken flavored or cornbread - 1 can cream of chicken soup - salt and pepper - 1 can cream of mushroom soup - 2 Tbsp. melted oleo - chicken broth Directions: - Combine Stove Top seasoning packet, bo...
# Metadatos: Doc ID=1809, Chunk ID=0
# --- Resultado 5 (Score: 9.3446) ---
# Contenido (inicio): Chicken Casserole Ingredients: - 2 c. diced, cooked chicken - 1 c. chopped celery - 1 c. cooked rice - 1 can cream of chicken soup - 3/4 c. mayonnaise - 1 c. chopped pecans - 1/2 c. melted butter - 1 diced onion Directions: - Mix all ingredients together in buttered casserole dish. Sprinkle grated c...
# Metadatos: Doc ID=990, Chunk ID=0

# %%
# --- 3. EL CEREBRO EN LA NUBE (API) ---
# Usamos esto para acceder a un modelo mucho más inteligente (7B)
# sin que se estalle la memoria de tu Colab.

from huggingface_hub import InferenceClient

# 1. PON TU TOKEN AQUÍ (Gratis en hf.co/settings/tokens)
HF_TOKEN = "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"  # <--- ¡PEGA TU TOKEN AQUÍ!

# Usamos Mistral-7B-Instruct (Es excelente siguiendo instrucciones)
REPO_ID = "mistralai/Mistral-7B-Instruct-v0.2" # <--- Modelo actualizado

client = InferenceClient(model=REPO_ID, token=HF_TOKEN)

def rag_pipeline_cloud(pregunta_usuario: str):
    # --- PASO A: RETRIEVAL LOCAL (Tu buscador FAISS) ---
    # Esto sigue corriendo en tu máquina, es rápido y privado.
    docs_recuperados = retrieve_recipes(pregunta_usuario, k=3)

    if not docs_recuperados:
        return "No encontré recetas."

    # Preparamos el contexto
    contexto_texto = "\n\n".join([f"RECETA #{i+1}:\n{doc.page_content}" for i, doc in enumerate(docs_recuperados)])

    # --- PASO B: PROMPT ENGINEERING ---
    # Mistral es muy listo, no necesita tantas reglas, solo claridad.
    prompt_sistema = """
    Eres un Chef Experto bilingüe (Inglés-Español).
    Tu tarea es leer las recetas en inglés proporcionadas y explicar CÓMO hacerlas en español.

    REGLAS CRÍTICAS DE TRADUCCIÓN:
    1. Cocoa = CACAO en polvo (¡NO es maní/cacahuate!).
    2. Stick of butter = 1 Barra de mantequilla.
    3. Icing = Glaseado/Cubierta.

    Si hay varias opciones (ej. Icing y Cake), explica la receta del PASTEL (Cake), no solo la cubierta.
    """

    prompt_usuario = f"""
    CONTEXTO (RECETAS EN INGLÉS):
    {contexto_texto}

    PREGUNTA DEL USUARIO:
    {pregunta_usuario}

    Responde en Español con el Título, Ingredientes y Pasos.
    """

    # --- PASO C: LLAMADA A LA API (Nube) ---
    print(f"--- Consultando al Chef Mistral en la nube... ---")

    respuesta = client.chat_completion(
        messages=[
            {"role": "system", "content": prompt_sistema},
            {"role": "user", "content": prompt_usuario}
        ],
        max_tokens=1000,
        temperature=0.1  # Precisión máxima
    )

    return respuesta.choices[0].message.content

# --- PRUEBA FINAL ---
print("\n" + "="*50)
query = "¿Cómo hago un Mac and Cheese (Macarrones con queso) clásico?"
print(rag_pipeline_cloud(query))
print("="*50)
# Out:
# ==================================================
#
# --- 2. Consultando el RAG (Retrieval) ---
#
# Consulta: '¿Cómo hago un Mac and Cheese (Macarrones con queso) clásico?'
# Top 3 chunks más relevantes encontrados:
# --- Resultado 1 (Score: 10.4858) ---
# Contenido (inicio): Very Cheese-Y Macaroni Ingredients: - 8 oz. elbow macaroni - 1 c. broccoli florets - 4 Tbsp. butter - 2 Tbsp. flour - 2 c. low-fat milk - 1 c. shredded sharp Cheddar cheese - 1/2 c. grated Parmesan cheese - 1/2 tsp. salt - 1/4 tsp. cayenne pepper - 1/4 c. whole wheat bread crumbs Directions: - In me...
# Metadatos: Doc ID=1326, Chunk ID=0
# --- Resultado 2 (Score: 10.8721) ---
# Contenido (inicio): Macaroni And Cottage Cheese Ingredients: - 3 c. uncooked macaroni - 1 small carton cottage cheese - 1/2 stick butter - salt and pepper to taste Directions: - Cook macaroni until tender. - Drain. - Put into dish and mix in 1 small carton cottage cheese. - Brown butter in skillet and pour over mixture...
# Metadatos: Doc ID=933, Chunk ID=0
# --- Resultado 3 (Score: 11.3988) ---
# Contenido (inicio): Thomas Jefferson'S Macaroni And Cheese Pudding Ingredients: - 1/4 c. butter - 1/4 c. flour - 2 1/2 c. milk - 8 oz. (about 2 c.) grated sharp Cheddar cheese - 2 c. (1/2 lb.) elbow macaroni, prepared according to pkg. directions - 1 tsp. salt - pepper to taste Directions: - Preheat oven to 400°. - Mel...
# Metadatos: Doc ID=620, Chunk ID=0
# --- Consultando al Chef Mistral en la nube... ---
#  Title: Mac and Cheese (Macarrones con Queso) Clásico
#
# Ingredients:
# - 8 oz. (227 g) macaroni
# - 2 c. (473 ml) low-fat milk
# - 4 Tbsp. (57 g) mantequilla (butter)
# - 2 Tbsp. (30 g) harina (flour)
# - 2 c. (473 g) queso cheddar rallado (shredded sharp Cheddar cheese)
# - 1/2 c. (113 g) queso parmesano rallado (grated Parmesan cheese)
# - 1/2 tsp. sal (salt)
# - 1/4 tsp. pimienta picante (cayenne pepper)
# - 1/4 c. (60 g) pan rallado (whole wheat bread crumbs)
#
# Steps:
# 1. Hervir el macarroni según las instrucciones del paquete, hasta que queden al dente.
# 2. Drenar bien.
# 3. Llenar una olla de mediano tamaño con agua hasta las tres cuartas partes.
# 4. Hacerlo hervir.
# 5. Añadir brocolis en flores.
# 6. Reducir el fuego a medio y cocinar hasta que estén listos.
# 7. Retirar y dejar de lado.
# 8. Precalentar el horno a 175°C.
# 9. Saludar un plato de vidrio de 20 cm de diámetro.
# 10. En una olla de mediano tamaño, derretir la mantequilla.
# 11. Añadir la harina y mezclar hasta que quede suave.
# 12. Hacer fluir la leche lentamente, estirando continuamente, hasta que espesice, aproximadamente 3 minutos. Retirar del fuego.
# 13. Reservar 1/4 taza de queso Cheddar.
# 14. Mezclar el queso restante, Cheddar, Gruyère, Parmesano, sal y pimienta picante hasta que el queso se derrite. Añadir el macarroni y el brocolis.
# 15. Colocarlo en el plato.
# 16. Cocinar durante 15 minutos.
# 17. Sprinkle Cheddar y pan rallado en la cima; cocinar otros 15 minutos, hasta que quede bullicioso.
# ==================================================

# %%
test_questions = [
    "Necesito una receta de brownies con cacao.",
    "Tengo pollo y brócoli, ¿qué cocino?",
    "Quiero algo dulce para el desayuno.",
    "¿Cómo preparo cemento para construcción?", # Prueba negativa
    "Receta de macarrones con queso."
]

print("🛠️ INICIANDO BATERÍA DE PRUEBAS 🛠️\n")

for i, q in enumerate(test_questions):
    print(f"🔹 PRUEBA #{i+1}: {q}")
    try:
        # Llamamos a tu función de nube
        respuesta = rag_pipeline_cloud(q)
        print(f"🤖 RESPUESTA:\n{respuesta[:500]}...") # Imprimimos solo los primeros 500 caracteres
    except Exception as e:
        print(f"❌ ERROR: {e}")
    print("-" * 60 + "\n")
# Out:
# 🛠️ INICIANDO BATERÍA DE PRUEBAS 🛠️
#
# 🔹 PRUEBA #1: Necesito una receta de brownies con cacao.
#
# --- 2. Consultando el RAG (Retrieval) ---
#
# Consulta: 'Necesito una receta de brownies con cacao.'
# Top 3 chunks más relevantes encontrados:
# --- Resultado 1 (Score: 9.7485) ---
# Contenido (inicio): Best Brownies Ingredients: - 1/4 lb. butter - 1/2 c. cocoa - 2 c. sugar - 4 eggs - 2 tsp. vanilla - 1 1/2 c. flour - 1/4 tsp. salt - 1 c. flaked coconut Directions: - Preheat oven to 350°. - Melt the butter. - Pour into mixing bowl. - Beat in cocoa and sugar. - When mixture is smooth, beat in eggs, ...
# Metadatos: Doc ID=250, Chunk ID=0
# --- Resultado 2 (Score: 10.0534) ---
# Contenido (inicio): Brownies Ingredients: - 1 1/2 c. white sugar - 1 1/2 c. brown sugar - 4 Tbsp. cocoa - 2 c. flour - 6 eggs - 1 1/2 sticks oleo, melted - 1/2 c. milk - 1 tsp. vanilla - 1/4 tsp. salt - 1/2 c. nuts Directions: - Mix all ingredients together; add nuts. - Pour into a greased and floured cookie sheet. - B...
# Metadatos: Doc ID=340, Chunk ID=0
# --- Resultado 3 (Score: 10.2776) ---
# Contenido (inicio): A & P Brownies Ingredients: - 10 Tbsp. butter - 2/3 c. cocoa - 3 or 4 eggs - 2 c. sugar - 2 tsp. vanilla - 1 c. flour - 1/2 tsp. salt Directions: - Melt butter on low heat. - Add 2/3 cup cocoa. - Stir until blended. - Remove from heat. - In a separate bowl, beat 3 or 4 eggs and sugar until lemon in ...
# Metadatos: Doc ID=1336, Chunk ID=0
# --- Consultando al Chef Mistral en la nube... ---
# 🤖 RESPUESTA:
#  Title: Receta de Brownies deliciosos con cacao
#
# Ingredientes:
# - 1 libra (454g) de mantequilla
# - 1/2 taza (45g) de cacao en polvo
# - 4 tazas (800g) de azúcar (2 tazas blancas y 2 de brown)
# - 4 huevos
# - 2 cucharadas (10ml) de extracto de vainilla
# - 3 o 4 tazas (450g) de harina
# - 1 cucharadita (5g) de sal
# - 1 taza (115g) de copas de coco (opcional)
#
# Pasos:
# 1. Calentar el horno a 175°C.
# 2. Fundir la mantequilla.
# 3. Verterla en un recipiente de mezcla.
# 4. Batir en ella el cacao y el azúcar hasta que ...
# ------------------------------------------------------------
#
# 🔹 PRUEBA #2: Tengo pollo y brócoli, ¿qué cocino?
#
# --- 2. Consultando el RAG (Retrieval) ---
#
# Consulta: 'Tengo pollo y brócoli, ¿qué cocino?'
# Top 3 chunks más relevantes encontrados:
# --- Resultado 1 (Score: 9.0919) ---
# Contenido (inicio): V. Mc'S Chicken And Broccoli Ingredients: - 1 Tbsp. margarine or butter - 4 skinless, boneless chicken breast halves - 1 can broccoli cheese soup - 1/3 c. water or milk - 2 c. broccoli flowerets - 1/8 tsp. pepper Directions: - Over medium heat, heat margarine in small skillet. - Cook the chicken for...
# Metadatos: Doc ID=1147, Chunk ID=0
# --- Resultado 2 (Score: 9.0948) ---
# Contenido (inicio): Chicken Divan Ingredients: - 2 whole chicken breasts - 20 oz. pkg. chopped frozen broccoli - 2 cans cream of celery soup - 1 tsp. curry powder - 2 tsp. lemon juice - 6 to 8 slices American cheese - 8 oz. sharp Cheddar cheese - 1 c. plain bread crumbs - 1/2 stick margarine Directions: - Butter sides ...
# Metadatos: Doc ID=985, Chunk ID=0
# --- Resultado 3 (Score: 9.1201) ---
# Contenido (inicio): Chicken And Broccoli Casserole Ingredients: - 1 lb. boneless chicken, cut up into cubes - 1 box frozen chopped broccoli, thawed - 1 can cream of mushroom soup - 1 c. sour cream - 1/2 lb. Velveeta cheese, cubed - 2 c. Pepperidge Farm bread crumbs Directions: - In greased casserole dish, mix chicken, ...
# Metadatos: Doc ID=1012, Chunk ID=0
# --- Consultando al Chef Mistral en la nube... ---
# 🤖 RESPUESTA:
#  Title: Pollo con Brócoli (Chicken and Broccoli)
#
# Ingredientes:
# - 1 libra (1 kg) de pollo cortado en cubos
# - 1 bolsa congelada de brócoli picado, descongelado
# - 1 lata de sopa de hongos de setas (cream of mushroom soup)
# - 1 taza (250 ml) de crema agria (sour cream)
# - 1/2 libra (227 g) de Queso Velveeta, cortado en cubos
# - 2 tazas (475 ml) de pan rallado de Pepperidge Farm
#
# Pasos:
# 1. Precalentar el horno a 350°F (175°C).
# 2. En una fuente de cocina, calentar la sopa de mantequilla o mantequilla ha...
# ------------------------------------------------------------
#
# 🔹 PRUEBA #3: Quiero algo dulce para el desayuno.
#
# --- 2. Consultando el RAG (Retrieval) ---
#
# Consulta: 'Quiero algo dulce para el desayuno.'
# Top 3 chunks más relevantes encontrados:
# --- Resultado 1 (Score: 18.5718) ---
# Contenido (inicio): Good Sweet Muffins Ingredients: - 1 egg - 1/2 c. milk - 1/4 c. vegetable oil - 1 1/2 c. flour - 1/2 c. sugar - 2 tsp. baking powder - 1/2 tsp. salt - 1 c. blueberries (optional) Directions: - Heat oven to 400°. - Beat egg with fork. - Add remaining ingredients except blueberries and stir until flour...
# Metadatos: Doc ID=124, Chunk ID=0
# --- Resultado 2 (Score: 19.5813) ---
# Contenido (inicio): Cold Bread Pudding Ingredients: - cold biscuits (crumbled) - sweet milk (for soaking) - 1 Tbsp. butter (cut into pieces) - 4 eggs, beaten - 2 cups sugar Directions: - One mixing bowl of crumbled up cold biscuits soaked in sweet milk. Add butter, sugar and eggs. Spray your pan with Pam, pour in mixtu...
# Metadatos: Doc ID=753, Chunk ID=0
# --- Resultado 3 (Score: 19.6288) ---
# Contenido (inicio): Sour Cream Pound Cake Ingredients: - 6 eggs - 2 3/4 c. sugar - 1 c. butter - 3 c. sifted plain flour - 1/2 tsp. salt - 1/4 tsp. soda - 1 c. sour cream - 1/2 tsp. vanilla extract - 1/2 tsp. lemon extract - 1/2 tsp. orange extract Directions: - In mixing bowl cream together sugar and butter until ligh...
# Metadatos: Doc ID=804, Chunk ID=0
# --- Consultando al Chef Mistral en la nube... ---
# 🤖 RESPUESTA:
#  Title: Panqueques dulces de manzana (Good Sweet Muffins)
#
# Ingredientes: - 1 huevo - 1 taza de leche - 1/4 taza de aceite vegetal - 3 tazas de harina - 1 taza de azúcar - 2 cucharadas de polvo para hornear - 1 taza de bayas azules (opcional)
#
# Pasos: - Calienta el horno a 204°C. - Batá el huevo con una fork. - Agregue los demás ingredientes excepto las bayas y mezcle hasta que la harina quede húmeda. La masa debe estar lisas con puntitos. - Agregue las bayas, si desea. - Llené las tazas de panque...
# ------------------------------------------------------------
#
# 🔹 PRUEBA #4: ¿Cómo preparo cemento para construcción?
#
# --- 2. Consultando el RAG (Retrieval) ---
#
# Consulta: '¿Cómo preparo cemento para construcción?'
# Top 3 chunks más relevantes encontrados:
# --- Resultado 1 (Score: 20.9670) ---
# Contenido (inicio): Earthquake Cake Ingredients: - 1 c. chopped pecans - 1 c. coconut - 1 German chocolate cake mix - 1 (8 oz.) pkg. Philadelphia cream cheese - 1 stick margarine - 1 box powdered sugar - 1 tsp. vanilla Directions: - Preheat oven to 350°. - Grease well a 9 x 13-inch sheet pan. Put coconut on bottom of p...
# Metadatos: Doc ID=1975, Chunk ID=0
# --- Resultado 2 (Score: 21.9969) ---
# Contenido (inicio): Earthquake Cake Ingredients: - 1 c. chopped nuts - 1 c. coconut - 1 stick margarine or butter - 1 (2 oz.) pkg. cream cheese - 1 box 10x powdered sugar - 1 box German chocolate cake mix Directions: - Preheat oven to 350°. - Grease and flour sheet cake pan (9 x 13-inch). - Sprinkle nuts and coconut in...
# Metadatos: Doc ID=1476, Chunk ID=0
# --- Resultado 3 (Score: 22.3051) ---
# Contenido (inicio): Earthquake Cake Ingredients: - 1 1/2 c. chopped pecans - 1 1/2 c. shredded coconut - 1 box German chocolate cake mix - 1/2 c. oleo or margarine - 1 (8 oz.) pkg. cream cheese - 3 c. 4x sugar Directions: - Prepare cake mix according to package directions. - Grease 9 x 13-inch pan. - Combine pecans and...
# Metadatos: Doc ID=507, Chunk ID=0
# --- Consultando al Chef Mistral en la nube... ---
# 🤖 RESPUESTA:
#  Lo siento, la pregunta no está relacionada con la receta. Aquí están las traducciones de las recetas de "Earthquake Cake" en español:
#
# Título: Torta Terremoto
# Receta #1:
# Ingredientes: - 1 taza de nueces picadas - 1 taza de coco - 1 paquete de 453g de mezcla de pastel de chocolate alemán - 1 (8 onzas) paquete de queso crema Philadelphia - 1 paleta de mantequilla - 1 bolsa de azúcar en polvo - 1 cucharadita de vanilla
# Instrucciones: - Calentar el horno a 175°C. - Saludar bien un plato de 23 x 33 ...
# ------------------------------------------------------------
#
# 🔹 PRUEBA #5: Receta de macarrones con queso.
#
# --- 2. Consultando el RAG (Retrieval) ---
#
# Consulta: 'Receta de macarrones con queso.'
# Top 3 chunks más relevantes encontrados:
# --- Resultado 1 (Score: 10.2390) ---
# Contenido (inicio): Very Cheese-Y Macaroni Ingredients: - 8 oz. elbow macaroni - 1 c. broccoli florets - 4 Tbsp. butter - 2 Tbsp. flour - 2 c. low-fat milk - 1 c. shredded sharp Cheddar cheese - 1/2 c. grated Parmesan cheese - 1/2 tsp. salt - 1/4 tsp. cayenne pepper - 1/4 c. whole wheat bread crumbs Directions: - In me...
# Metadatos: Doc ID=1326, Chunk ID=0
# --- Resultado 2 (Score: 10.6643) ---
# Contenido (inicio): Macaroni And Cottage Cheese Ingredients: - 3 c. uncooked macaroni - 1 small carton cottage cheese - 1/2 stick butter - salt and pepper to taste Directions: - Cook macaroni until tender. - Drain. - Put into dish and mix in 1 small carton cottage cheese. - Brown butter in skillet and pour over mixture...
# Metadatos: Doc ID=933, Chunk ID=0
# --- Resultado 3 (Score: 10.8724) ---
# Contenido (inicio): Macaroni And Cheese Casserole Ingredients: - 1 lb. sharp cheese, grated - 8 oz. macaroni, cooked and drained - 1 can condensed cream of mushroom soup - 2 oz. jar pimento - 1 c. mayonnaise - 1/2 onion, grated Directions: - Mix all ingredients. - Before baking, cover with crumbled cheese crackers and ...
# Metadatos: Doc ID=916, Chunk ID=0
# --- Consultando al Chef Mistral en la nube... ---
# 🤖 RESPUESTA:
#  Título: Macarrones con Queso
#
# Ingredientes:
# - 8 onzas (227 g) macarrones secos
# - 1 taza (227 g) brocoli flores
# - 4 cucharadas (170 g) mantequilla
# - 2 cucharadas (30 g) harina
# - 2 tazas (946 ml) leche descremada
# - 2 tazas (907 g) queso Cheddar rallado
# - 1/2 taza (113 g) queso Parmesano rallado
# - 1/2 cucharadita (1,5 g) sal
# - 1/4 cucharadita (1 g) pimienta picante
# - 1/4 taza (60 g) pan rallado integral
#
# Pasos:
# 1. Hierva el macarrones según las instrucciones del paquete, hasta que queden al dente....
# ------------------------------------------------------------
